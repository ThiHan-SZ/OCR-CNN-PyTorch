# %% [markdown]
# ## Conclusion

# %% [markdown]
# Over the various models tested we have been able to generate the training and validation losses of each model over the training epochs as well as the resultant accuracy and confusion matrices of the data.
#
# From this we can rank the Models by their accuracies.
#
# | Model                                        | Training Loss | Validation Loss | Accuracy |
# |:--------------------------------------------:|:-------------:|:---------------:|:--------:|
# | Single Convolution (32) w/ GELU              |     3.0301    |      3.0981     |   0.814  |
# | KNN (6 Neighbours)                           |       NA      |        NA       |   0.785  |
# | Single Convolution (64) w/ GELU              |     3.0875    |      3.1405     |   0.743  |
# | Deep CNN Model [LR Drop on Plateau] w/ GELU  |     3.1446    |      3.1564     |   0.724  |
# | Deep CNN Model w/ GELU                       |     3.1797    |      3.1899     |   0.697  |
# | Deep CNN Model [Bigger Model] w/ GELU        |     3.1793    |      3.1944     |   0.696  |
# | Deep CNN Model w/ RELU                       |     3.4148    |      3.4173     |   0.464  |
#
# We can see that bigger models don't always mean better and that neural networks and deep learners aren't the be all end all solution.\
# While they can achieve marginally better results, the computational cost and time cost may outweigh the benefits of using simpler models like the KNN models.
#
# Another point to note is in how GELU may be better in activation functions of AI Models as RELU can end up creating a non-differentiable point at the inflection point of the RELU function (when the system goes from <= 0 to > 0 )

# %% [markdown]
# ## Introducing Neural Networks
#
# In the world of AI/ML, the current big thing after the support vector machines are what we call perceptrons (Neural Networks) or multi-layer perceptron (Deep Learning Networks).\
# For images and 2-Dimensional data, one can represent the image as a 2D array of numbers corresponding to each pixel's colour and thereby create a data type that can be manipulated and trained upon.\
# One of the key mathematical operations used to extract features from a 2D image is using what is known as a convolution. Essentially, a filter of size N*N is used to transform the image by sliding said filter along the image ensuring that the filter stays within the bounds of the image.\
# Thereby, depending on the values withing the cells of the filter, we can extract features from an image by multiplying the channels of the image with the filters.

# %%
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.nn import functional as F
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ### Hyperparameters

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
batch_size = 64
max_epoch = 10
train_iters = 5000
alpha = 0.0001
decay = 0.00001
eval_iters = 1000
dropout = 0.5
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# ### Training Data Reading and Map generation

# %%
# Load training data Set
with open("OCR Neural Network/Datasets/emnist-balanced-train.csv", "r") as f:
    reader = csv.reader(f)
    data_clump = np.array(list(reader), dtype=np.uint8)

# %%
maps = open("OCR Neural Network/Datasets/emnist-balanced-mapping.txt",'r')
maps = {i:chr(int(j)) for i,j in [line.split() for line in maps.readlines()]}

# %% [markdown]
# ### Test Data Reading

# %%
with open("OCR Neural Network/Datasets/emnist-balanced-test.csv", "r") as f:
    reader = csv.reader(f)
    test_data_clump = np.array(list(reader), dtype=np.uint8)

# %% [markdown]
# ### Data pre processing

# %%
#creating the training set
head_train = data_clump[:,0] 
img_px_train = data_clump[:,1:]

#normalizing the data
trainmean = np.mean(img_px_train)
trainstd = np.std(img_px_train)
img_px_train = (img_px_train - trainmean) / trainstd
img_px_train = img_px_train.reshape(-1, 28, 28)

#creating the test set
head_test = test_data_clump[:,0] 
img_px_test = test_data_clump[:,1:]

#normalizing the data
img_px_test = (img_px_test - trainmean) / trainstd
img_px_test = img_px_test.reshape(-1, 28, 28)


'''
No need to reshape and use pillow to convert to image.
EMNIST dataset already has rotations embedded in it.
'''
frame_train = pd.DataFrame({'Label' : head_train,  'Image' : img_px_train.tolist()})
frame_test = pd.DataFrame({'Label' : head_test,  'Image' : img_px_test.tolist()})

# %%
def get_batch(split):
    data = frame_train if split == 'train' else frame_test
    data = data.sample(batch_size)
    X = torch.tensor(data['Image'].values.tolist(), dtype=torch.float32).view(-1, 1, 28, 28)
    y = torch.tensor(data['Label'].values.tolist(), dtype=torch.long)
    X,y = X.to(device), y.to(device)
    return X, y

# %% [markdown]
# ### Designing the CNN Layers for Processing
# * A CNN or Convolution Neural Network applies Convultions on values input.
#
# * In a CNN, each node is a convoltuion alogrithm with some specified weight of convolution, a value to multiply the underlying value by. Suppose w1 for n1 is defined as 0.5, then the convolution will take w1*p1 for the case of the output x1
#
# * In the CNN Layer, a 2D Convolution then takes in the entire image (grey scale 1 channel) and spits out a series of maps that with channels of N_out_channels.
#
# * These channels could embed features in the weights or such. Each weight is mapped by the kernel so, if kernal is N size, there will be $N^2$ weights

# %%
class CNNLayer(nn.Module):
    #Define the first layer of the CNN
    def __init__(self, *args, **kwargs) -> None:
        super(CNNLayer, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=16, kernel_size=3)
        self.conv2 = nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.conv3 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3)
        self.conv4 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.fc1 = nn.Linear(32*4*4, 512)
        self.fc2 = nn.Linear(512, 128)
        self.fc3 = nn.Linear(128, 47)

        self.activation = nn.ReLU()
        self.dropout = nn.Dropout(p=dropout)
        self.output_activation = nn.ReLU()
    
    def forward(self, x):
        out = self.activation(self.conv1(x))
        out = self.activation(self.conv2(out))
        out = self.pool1(out)
        out = self.dropout(out)

        out = self.activation(self.conv3(out))
        out = self.activation(self.conv4(out))
        out = self.pool2(out)
        out = self.dropout(out)

        out = out.view(-1, 32*4*4)
        out = self.output_activation(self.fc1(out))
        out = self.output_activation(self.fc2(out))
        out = F.softmax(self.fc3(out))
        return out

# %% [markdown]
# ### Creating the Model

# %%
class OCRCNN(nn.Module):
    def __init__(self, *args, **kwargs) -> None:
        super(OCRCNN, self).__init__()
        self.hidden = CNNLayer()

    def forward(self, x, train_target = None):
        
        # Run through the Main Hidden Layers of the CNN
        out = self.hidden(x)

        if train_target is not None:
            loss = F.cross_entropy(out, train_target)
            return out, loss
        
        return out,None
    
    def predict(self, frame, size):
        frame = frame.sample(size)
        X = torch.tensor(frame['Image'].values.tolist(), dtype=torch.float32).view(-1, 1, 28, 28)
        y = np.array(frame['Label'].values.tolist(), dtype=np.int64)
        
        X, y = X.to(device), torch.tensor(y).to(device)
        
        self.eval()  # Set model to evaluation mode
        with torch.no_grad():
            out = self.hidden(X)
            _, predicted = torch.max(out, 1)
        
        conf_matrix = confusion_matrix(y.cpu(), predicted.cpu())
        print([maps[str(i)] for i in predicted.cpu().numpy()])
        print([maps[str(i)] for i in y.cpu().numpy()])
        plt.imshow(conf_matrix, cmap='hot', interpolation='nearest')
        plt.colorbar()
        plt.show()
        
        return None

# %%
model = OCRCNN()
m = model.to(device)

sum(p.numel() for p in m.parameters()),"parameters"
# Out:
# (350751, 'parameters')

# %%
Counter = 0
train_losses = []
val_losses = []

# %%
#Adjustment For Plateau
aplha = 1e-6
decay = 1e-7

# %%
@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# %%
optimizer = torch.optim.AdamW(m.parameters(), lr=alpha, weight_decay=decay)

for epoch in range(max_epoch):
    model.train()
    for i in range(train_iters):

        if i % eval_iters == 0 or i == train_iters - 1:
            losses = estimate_loss()
            train_losses.append(losses['train'])
            val_losses.append(losses['val'])
            print(f'Epoch {epoch}, Iteration {Counter}')
            print(f'Training Loss: {train_losses[-1]:.4f}, Validation Loss: {val_losses[-1]:.4f}')
            Counter += 1000

        
        X_tr, Y_tr = get_batch('train')

        optimizer.zero_grad()

        out,loss = m(X_tr, Y_tr)

        loss.backward()
        optimizer.step()
# Out:
# C:\Users\Destiny\AppData\Local\Temp\ipykernel_41128\3938324615.py:35: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   out = F.softmax(self.fc3(out))
# Epoch 0, Iteration 60000
# Training Loss: 3.1762, Validation Loss: 3.1905
# Epoch 0, Iteration 61000
# Training Loss: 3.1775, Validation Loss: 3.1905
# Epoch 0, Iteration 62000
# Training Loss: 3.1799, Validation Loss: 3.1920
# Epoch 0, Iteration 63000
# Training Loss: 3.1824, Validation Loss: 3.1902
# Epoch 0, Iteration 64000
# Training Loss: 3.1806, Validation Loss: 3.1917
# Epoch 0, Iteration 65000
# Training Loss: 3.1762, Validation Loss: 3.1842
# Epoch 1, Iteration 66000
# Training Loss: 3.1791, Validation Loss: 3.1872
# Epoch 1, Iteration 67000
# Training Loss: 3.1779, Validation Loss: 3.1882
# Epoch 1, Iteration 68000
# Training Loss: 3.1827, Validation Loss: 3.1909
# Epoch 1, Iteration 69000
# Training Loss: 3.1753, Validation Loss: 3.1881
# Epoch 1, Iteration 70000
# Training Loss: 3.1725, Validation Loss: 3.1865
# Epoch 1, Iteration 71000
# Training Loss: 3.1785, Validation Loss: 3.1883
# Epoch 2, Iteration 72000
# Training Loss: 3.1738, Validation Loss: 3.1862
# Epoch 2, Iteration 73000
# Training Loss: 3.1732, Validation Loss: 3.1835
# Epoch 2, Iteration 74000
# Training Loss: 3.1727, Validation Loss: 3.1844
# Epoch 2, Iteration 75000
# Training Loss: 3.1746, Validation Loss: 3.1852
# Epoch 2, Iteration 76000
# Training Loss: 3.1733, Validation Loss: 3.1831
# Epoch 2, Iteration 77000
# Training Loss: 3.1754, Validation Loss: 3.1860
# Epoch 3, Iteration 78000
# Training Loss: 3.1741, Validation Loss: 3.1858
# Epoch 3, Iteration 79000
# Training Loss: 3.1682, Validation Loss: 3.1843
# Epoch 3, Iteration 80000
# Training Loss: 3.1716, Validation Loss: 3.1832
# Epoch 3, Iteration 81000
# Training Loss: 3.1756, Validation Loss: 3.1899
# Epoch 3, Iteration 82000
# Training Loss: 3.1718, Validation Loss: 3.1842
# Epoch 3, Iteration 83000
# Training Loss: 3.1723, Validation Loss: 3.1841
# Epoch 4, Iteration 84000
# Training Loss: 3.1731, Validation Loss: 3.1847
# Epoch 4, Iteration 85000
# Training Loss: 3.1716, Validation Loss: 3.1805
# Epoch 4, Iteration 86000
# Training Loss: 3.1580, Validation Loss: 3.1663
# Epoch 4, Iteration 87000
# Training Loss: 3.1529, Validation Loss: 3.1653
# Epoch 4, Iteration 88000
# Training Loss: 3.1504, Validation Loss: 3.1676
# Epoch 4, Iteration 89000
# Training Loss: 3.1547, Validation Loss: 3.1626
# Epoch 5, Iteration 90000
# Training Loss: 3.1534, Validation Loss: 3.1640
# Epoch 5, Iteration 91000
# Training Loss: 3.1518, Validation Loss: 3.1648
# Epoch 5, Iteration 92000
# Training Loss: 3.1526, Validation Loss: 3.1641
# Epoch 5, Iteration 93000
# Training Loss: 3.1514, Validation Loss: 3.1658
# Epoch 5, Iteration 94000
# Training Loss: 3.1515, Validation Loss: 3.1639
# Epoch 5, Iteration 95000
# Training Loss: 3.1518, Validation Loss: 3.1625
# Epoch 6, Iteration 96000
# Training Loss: 3.1501, Validation Loss: 3.1660
# Epoch 6, Iteration 97000
# Training Loss: 3.1540, Validation Loss: 3.1630
# Epoch 6, Iteration 98000
# Training Loss: 3.1504, Validation Loss: 3.1674
# Epoch 6, Iteration 99000
# Training Loss: 3.1536, Validation Loss: 3.1632
# Epoch 6, Iteration 100000
# Training Loss: 3.1512, Validation Loss: 3.1661
# Epoch 6, Iteration 101000
# Training Loss: 3.1492, Validation Loss: 3.1588
# Epoch 7, Iteration 102000
# Training Loss: 3.1503, Validation Loss: 3.1615
# Epoch 7, Iteration 103000
# Training Loss: 3.1496, Validation Loss: 3.1660
# Epoch 7, Iteration 104000
# Training Loss: 3.1470, Validation Loss: 3.1641
# Epoch 7, Iteration 105000
# Training Loss: 3.1490, Validation Loss: 3.1630
# Epoch 7, Iteration 106000
# Training Loss: 3.1508, Validation Loss: 3.1632
# Epoch 7, Iteration 107000
# Training Loss: 3.1472, Validation Loss: 3.1589
# Epoch 8, Iteration 108000
# Training Loss: 3.1439, Validation Loss: 3.1634
# Epoch 8, Iteration 109000
# Training Loss: 3.1485, Validation Loss: 3.1634
# Epoch 8, Iteration 110000
# Training Loss: 3.1494, Validation Loss: 3.1640
# Epoch 8, Iteration 111000
# Training Loss: 3.1463, Validation Loss: 3.1608
# Epoch 8, Iteration 112000
# Training Loss: 3.1460, Validation Loss: 3.1608
# Epoch 8, Iteration 113000
# Training Loss: 3.1487, Validation Loss: 3.1619
# Epoch 9, Iteration 114000
# Training Loss: 3.1456, Validation Loss: 3.1632
# Epoch 9, Iteration 115000
# Training Loss: 3.1500, Validation Loss: 3.1627
# Epoch 9, Iteration 116000
# Training Loss: 3.1481, Validation Loss: 3.1667
# Epoch 9, Iteration 117000
# Training Loss: 3.1473, Validation Loss: 3.1620
# Epoch 9, Iteration 118000
# Training Loss: 3.1489, Validation Loss: 3.1612
# Epoch 9, Iteration 119000
# Training Loss: 3.1446, Validation Loss: 3.1564

# %%
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.show()
print('Training Done')
m.predict(frame_test, 100)
# Out:
# Training Done
# ['P', 'C', 'V', 'T', '0', 'd', 'B', 'd', '2', 'J', '6', 'f', 'E', 'h', 'd', 'S', 'f', 'J', '6', '6', 'K', 'F', 'F', '0', '9', 'd', 'V', '7', 'A', 'X', 'E', 'E', '9', 'S', 'Y', '2', 'h', 'Y', 'E', 'J', 'J', 'r', '9', 'g', 'M', 'a', 'a', '6', 'B', 'E', 'H', 'P', 'a', 'D', 'C', '9', 'G', 'W', 'Y', 'I', 'Y', 'V', 'W', 'H', 'E', '6', 'a', '3', 'V', '0', 'd', 'E', 'H', 'W', 'W', 'h', 'f', 'P', 'V', '2', 'd', '1', 'U', 'f', 'E', '0', 'f', 'B', 'A', 'C', '3', '2', 'L', '8', '1', 'Y', '9', 'A', '0', '8']
# ['P', 'e', 'V', 't', '0', 'd', 'G', 'd', 'Z', 'J', 'b', 'F', 'E', 'h', 'd', '5', 'f', 'J', '6', '6', 'K', 'f', 'f', '0', 'g', 'd', 'V', '7', 'R', 'X', 'e', 'e', '9', 'S', 'Y', '2', 'b', 'N', 'E', 'J', 'J', 'r', 'g', 'g', 'M', 'a', 'a', 'b', 'B', 'e', 'H', 'R', 'a', 'O', 'C', 'g', 'G', 'W', 'Y', 'I', '4', 'V', 'W', '4', 'E', 'b', 'a', '3', 'V', '0', 'd', 'E', 'H', 'W', 'N', 'h', 'f', 'P', 'V', 'd', 'd', '1', 'U', 'F', 'E', '0', 't', 'B', 'A', 'C', '3', 'Z', 'L', '8', 'I', 'Y', 'q', 'A', '0', '8']
# C:\Users\Destiny\AppData\Local\Temp\ipykernel_41128\3938324615.py:35: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   out = F.softmax(self.fc3(out))

# %% [markdown]
# ### Checking State Dicts of Model and Optim

# %%
print('Model State Dict')
for param_tensor in model.state_dict():
    print(param_tensor, "\t", model.state_dict()[param_tensor].size())

# %%
print('Optimizer State Dict')
for var_name in optimizer.state_dict():
    print(var_name, "\t", optimizer.state_dict()[var_name])

# %% [markdown]
# ### Saving Model Checkpoint

# %%
torch.save(model.state_dict(), 'OCR Neural Network/OCRModel_3.1446_3.1564.pth')

# %%
torch.save(optimizer.state_dict(), 'OCR Neural Network/Optimizer_3.1446_3.1564.pth')

# %%
@torch.no_grad()
def estimate_loss():
    out = {}
    model2.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model2(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    out['accuracy'] = get_accuracy()
    model2.train()
    return out

@torch.no_grad()
def get_accuracy():
    model2.eval()
    correct = 0
    total = 0
    for i in range(1000):
        X, Y = get_batch('val')
        logits, _ = model2(X, Y)
        _, predicted = torch.max(logits, 1)
        total += Y.size(0)
        correct += (predicted == Y).sum().item()
    model2.train()
    return correct / total

# %%
model2 = OCRCNN()
model2.load_state_dict(torch.load(r'C:\Jupyters\OCR Neural Network\OCR_3.4148_3.4173 ReLU Chain\OCRModel_3.4148_3.4173.pth'))
model2.eval()
model2 = model2.to(device)
model2.predict(frame_test, frame_test.shape[0])
get_accuracy()
# Out:
# C:\Users\Destiny\AppData\Local\Temp\ipykernel_20736\1056086961.py:35: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   out = F.softmax(self.fc3(out))
# ['a', 'W', '3', '0', 'g', 'T', 'H', 'I', 'E', 'E', 'T', 'a', 'g', 'H', '3', 'g', 'E', 'W', 'h', 'h', 'H', 'E', '1', '3', 'C', 'E', '9', 'E', '6', '1', '1', 'I', 'T', 'Y', 'M', 'I', '3', 'E', 'b', 'M', 'U', 'P', 'E', 'E', '6', 'U', 'd', 'g', 'd', 'J', 'I', '6', 'f', 'a', '0', 'J', 'b', 'a', 'b', '6', 'W', 'E', 'E', 'C', 'C', 'E', 'W', 'E', 'a', 'W', 'M', 'W', '0', 'a', '0', 'n', '0', '0', '6', 'E', '3', 'b', '6', 'M', 'a', '1', 'g', 'L', 'a', '3', 'Y', 'J', 'f', 'T', 'd', '9', 'L', '6', 'H', '3', 'h', 'K', 'g', 'b', 'E', '6', 'n', '3', 'E', 'h', 'E', 'a', 'K', '9', 'g', 'K', '0', 'n', 'K', 'a', 'n', 'Y', 'n', 'g', 'h', 'a', 'E', 'T', '3', 'h', 'C', 'E', 'g', 'E', 'Y', 'a', 'W', 'b', '3', 'E', 'E', 'P', 'a', 'b', 'L', '6', 'Y', 'M', 'a', 'C', 'U', 'g', 'W', '0', 'H', '0', 'I', 'P', '9', 'n', 'd', 'a', 'T', 'U', 'W', 'C', 'a', '9', '9', 'Y', 'f', '1', 'a', 'C', 'Y', 'U', '3', 'C', 'E', 'f', 'C', 'g', '9', 'n', 'g', '6', 'a', 'W', 'n', '6', 'E', 'g', '1', '6', 'E', 'K', 'U', '0', 'L', 'E', '1', '0', 'a', 'P', '9', '3', 'H', '0', 'f', 'g', 'a', 'Y', 'K', 'g', 'a', 'n', 'Y', 'K', 'C', '9', '3', 'a', 'g', 'Y', 'C', 'U', 'C', 'b', 'P', 'T', 'J', 'M', 'g', 'W', 'f', 'b', '0', 'd', 'J', 'T', '6', 'L', 'g', '3', 'I', 'U', 'W', '6', '3', '1', 'Y', 'E', 'C', 'J', 'I', '0', 'a', 'g', '3', 'P', 'E', 'K', 'E', 'J', 'L', 'a', '0', 'W', '3', 'T', 'f', '0', 'C', 'H', 'g', 'W', 'J', 'T', 'g', '9', 'W', '6', 'g', 'n', 'K', 'a', 'E', 'C', '3', 'W', '0', 'a', 'a', '3', 'K', 'I', '9', 'I', 'a', 'E', '9', 'a', 'M', 'E', 'P', '9', 'Y', '6', 'T', 'J', '0', 'n', '9', 'a', 'g', '0', '3', 'E', 'E', 'g', '3', 'g', 'H', 'P', 'P', 'M', '6', 'a', '0', '1', '0', '0', '0', 'M', '0', 'U', 'C', 'P', '1', 'C', 'Y', 'E', '0', 'a', '1', 'E', 'I', 'W', '3', 'H', 'f', 'W', 'J', 'g', 'f', 'a', 'C', '3', 'K', 'W', '0', 'h', 'g', 'g', '0', '3', 'C', 'H', '6', '6', 'g', 'K', '0', '3', 'b', 'P', 'f', 'a', 'C', 'E', 'Y', 'g', 'M', '9', '1', '0', 'E', '9', 'E', 'n', 'n', 'T', '1', 'E', 'f', 'J', 'g', 'd', 'W', '1', 'T', 'n', 'a', 'f', 'M', 'd', 'E', 'E', 'J', 'J', 'a', 'C', 'U', 'f', 'C', '9', 'C', 'Y', 'I', 'Y', 'g', 'g', 'g', 'C', 'H', 'E', 'W', '0', 'a', 'W', 'f', 'T', '1', '3', 'Y', 'K', 'g', 'Y', '6', 'f', 'U', 'g', 'h', 'M', 'g', '6', '6', 'E', 'Y', 'E', 'W', 'K', '1', 'Y', 'T', 'H', 'M', 'P', '3', 'C', 'P', 'W', 'K', 'J', 'W', 'W', 'h', 'a', 'E', 'W', '9', 'n', 'H', 'g', 'n', 'n', '1', 'f', 'g', '9', 'W', 'b', '6', 'b', 'J', 'E', '0', 'd', '0', 'U', 'W', 'b', '3', 'H', 'K', '9', 'K', 'J', 'E', 'd', 'h', '6', 'Y', 'H', 'M', 'J', 'f', '0', 'C', '6', 'g', 'E', 'g', '0', '9', 'W', 'C', 'C', 'g', 'f', 'g', 'U', 'a', 'H', 'd', '9', 'E', 'Y', 'C', '0', 'W', 'P', 'M', '9', '0', 'd', 'J', 'a', 'E', 'E', 'a', 'I', 'T', 'L', 'I', 'K', '6', 'W', 'd', '3', 'H', 'U', 'E', 'a', 'Y', 'E', 'n', 'K', 'n', 'E', '0', 'I', 'M', '1', '1', 'Y', 'f', 'f', 'h', 'K', 'P', 'W', 'H', 'b', 'n', 'E', 'a', 'g', '9', 'Y', '3', '3', 'b', 'f', 'g', 'P', 'g', '0', '0', 'J', '9', 'a', 'T', 'n', 'E', 'H', 'g', 'W', '9', 'K', 'g', 'g', 'U', 'b', 'E', 'C', 'f', 'h', '9', 'h', '3', 'K', '1', '9', 'f', 'n', 'E', 'H', 'K', 'g', '9', 'E', 'a', '3', '0', 'n', '0', 'b', 'W', 'a', '9', 'E', 'a', 'K', 'W', 'Y', 'H', 'H', 'J', '0', 'W', 'K', '0', 'M', 'I', 'f', 'K', 'a', 'b', 'E', 'g', 'f', 'M', 'Y', 'g', '9', 'M', 'n', 'Y', '1', 'E', '1', 'T', 'f', 'a', 'a', 'Y', 'h', '0', 'P', 'd', 'Y', 'E', 'E', 'Y', 'W', 'K', 'P', 'H', 'E', '3', 'E', 'E', 'W', 'Y', 'g', 'J', 'I', 'a', 'J', 'a', 'E', 'Y', 'I', 'H', 'h', '3', 'M', 'Y', 'H', 'U', 'Y', 'a', 'H', 'W', 'W', 'P', 'd', 'g', 'E', 'n', 'f', 'K', '0', '0', 'C', 'a', 'P', '0', 'Y', 'I', 'T', 'f', 'Y', 'J', 'W', 'M', '0', '3', 'a', 'f', 'C', 'g', 'a', 'Y', '3', 'P', 'K', 'M', '1', '0', 'f', 'b', 'K', 'I', 'C', 'f', '3', '9', 'J', 'T', '0', 'E', 'a', 'd', 'I', 'I', '3', '6', '9', 'E', 'b', 'C', '1', '6', 'C', 'M', 'K', 'n', 'f', 'g', 'g', 'I', '0', 'K', 'g', 'Y', 'Y', 'E', 'g', 'g', 'T', 'J', '0', 'g', 'g', 'H', 'E', 'H', 'M', 'H', 'E', '9', 'U', 'P', 'f', '3', '0', 'a', 'E', ...
# ['A', 'W', '3', 'D', '4', 'T', '4', 'I', 'e', 'S', 'T', 'Q', 'B', '4', 'D', 'q', 'e', 'W', 'h', 'A', 'Y', '5', 'I', 'Z', 'e', 'E', 'q', 'G', '6', 'L', 'L', 'I', 'T', 'Y', 'M', 'I', '3', 'E', 'b', 'M', 'U', 'P', '5', 'E', '6', 'U', 'd', 'q', 'J', 'I', 'I', 'G', 'f', 'U', 'D', 'I', 'b', 'R', 'b', 'G', 'V', 'e', 'E', 't', 'C', 'E', 'W', '5', 'a', 'N', 'M', 'W', '0', 'e', '0', 'n', 'A', 'd', 'G', 'e', '3', 'B', '6', 'M', '2', 'L', 'S', 'L', 'R', '2', 'V', 'Z', 'F', 'T', 'd', 'Y', 'L', '6', 'H', 'q', 'h', 'X', '8', 'b', 'E', '6', 'n', '3', 'E', 'h', 'e', '2', 'X', 'q', 'g', 'r', '0', 'n', 'K', '2', 'A', 'Y', 'n', 'q', 'h', 'r', 'G', '7', 'S', 'h', 'Z', 'e', '5', 'R', 'X', 'Z', 'W', 'b', 'Z', '2', 'Z', 'P', 'g', 'b', 'L', '6', 'V', 'M', 'Z', 'C', 'Y', 'R', 'N', '0', 'A', 'O', 'I', '7', 'g', 'n', 'd', '2', 'r', 'V', 'V', 'C', '2', '4', 'g', 'Y', 'f', 'I', 'Z', '8', 'V', 'J', '5', 'O', '5', 'f', 'C', 'S', '9', 'n', '8', '6', 'a', 'N', 'n', '6', '5', 'g', '1', 'G', 'G', 'R', 'U', 'O', 'L', 't', '1', 'O', 'Q', 'P', '7', '3', 'H', '0', 't', 'G', 'Z', 'Y', 'X', '5', 'Z', 'X', 'V', 'R', 'r', '9', 'Z', 'a', 'g', 'Y', 'E', 'U', 'C', '5', 'P', '7', 'J', 'n', 'G', 'N', 'F', '6', 'B', 'd', 'S', 'T', 'G', 'X', '5', '3', 'I', 'U', 'N', '6', 'S', 'L', 'Y', 'E', 'G', 'J', '1', 'O', 'g', 'f', '8', 'P', 'E', 'X', 'e', 'J', 'L', 'a', '0', 'W', '5', 't', 't', '0', 'C', 'A', 'g', 'W', 'J', 'T', 'g', '9', 'N', 'G', 'g', 'n', 't', 'a', '5', 'R', '3', 'W', 'O', '2', 'Q', '3', 'R', 'I', 'g', 'L', 'Q', '5', '7', 'Q', 'M', 'E', '7', '7', 'Y', '6', 'T', '5', 'D', 'n', '9', 'Z', 'q', 'D', 'S', 'E', 'S', 'Q', '2', 'q', 'A', 'P', 'P', 'M', '6', 'Z', '0', '1', '0', '0', 'O', 'A', 'O', 'U', 'C', 'P', 'I', 'C', '4', '5', 'D', 'I', 'L', 'S', 'I', 'W', '3', '4', 't', 'N', 'J', '8', 'f', 'B', 'S', 'D', 'R', 'W', 'O', 'h', '8', '5', '0', 'Z', 'r', '4', '6', '6', '5', 'R', 'D', '3', 'b', 'P', 'f', 'Q', 't', 'R', 'V', 'q', 'M', 'q', '1', 'D', 'E', 'g', 'E', 'n', 'n', 'r', '1', 'e', 'F', '5', 'g', '8', 'W', '1', 't', 'n', 'Q', 'Q', 'M', 'd', 'E', 'E', 'J', 'I', 'G', 'G', 'V', 'F', 'L', '9', 'C', 'Y', 'L', 'V', '8', 'B', 'q', 'C', '4', '5', 'W', '0', 'a', 'W', 'r', 'T', '1', '3', 'Y', 'K', 'q', 'V', 'G', 'F', 'V', 'g', 'h', 'M', 'G', '6', 'G', 'B', 'Y', 'g', 'W', 'X', 'I', 'Y', 'T', 'H', 'N', 'P', '5', 'C', 'R', 'W', 'K', 'S', 'W', 'N', 'h', '2', 'e', 'W', 'q', 'A', 'H', '5', 'n', 'R', 'L', 't', 'g', '9', 'N', 'r', '6', 'b', 'J', 'E', '0', 'd', 'Q', 'U', 'W', 'B', '5', 'A', 'X', '9', 'K', 'S', 'E', 'd', 'A', '6', '4', 'A', 'M', 'S', 't', '0', 'C', '6', 'S', 'E', 'Q', 'D', '9', 'N', 'C', 'C', 'g', 'f', 'g', 'U', 'R', 'H', 'd', '9', 'E', 'V', 'C', '0', 'W', 'P', 'P', '9', '0', 'd', 'I', '2', 'E', 'G', '2', '1', 'T', 'L', 'I', 'R', 'G', 'W', 'd', '2', '4', 'U', 'E', 'a', 'Y', 'G', 'n', 'K', 'n', 'S', '5', 'I', 'M', 'I', 'I', '4', 't', 'f', 'h', 'K', '7', 'W', 'H', 'G', 'n', 'e', '2', 'g', '9', 'Y', '3', '3', 'b', 'f', 'B', 'P', '8', '0', 'D', 'J', '9', 'a', 'T', 'n', 'E', 'H', 'G', 'W', '9', 'R', 'A', 'g', 'U', 'b', 'e', 'C', 'f', 'A', 'g', 'h', '3', 'X', '1', 'q', 't', 'n', 'R', 'H', 'K', 'Q', 'q', 'Z', 'G', '3', 'O', 'r', 'D', 'D', 'W', '2', '9', 'Z', 'a', 't', 'W', 'V', 'M', 't', 'J', 'O', 'N', 'X', 'Q', 'M', '1', 'F', 'K', 'Q', 'b', '8', '8', 'F', 'M', 'Y', '8', '9', 'V', 'n', 'Y', 'I', 'Z', '1', 'T', 'f', 'U', 'Q', 'V', 'h', '0', '2', 'd', 'Y', 'E', 'Z', 'Y', 'N', 'X', 'q', '4', '5', '3', 'b', 'e', 'V', 'V', 'g', 'D', 'X', 'a', 'J', 'a', 'R', 'V', 'L', '4', 'h', 'S', 'M', 'X', 'H', 'U', 'Y', '4', 'H', 'W', 'W', '2', 'd', 'g', '8', 'n', 'F', 'K', 'B', 'O', 'r', 'a', '8', 'O', 'Y', 'L', '7', 'A', '4', 'S', 'N', 'M', 'D', '3', 'a', 'G', 'C', 'q', 'a', 'r', 'S', 'P', 'K', 'M', '1', 'O', 'f', 'b', 'K', 'I', 'C', 'f', '3', 'Q', 'J', 'T', 'D', 'e', '2', 'd', 'L', 'I', 'Z', '6', 'q', 'R', '6', 'C', 'I', '6', 'C', 'M', 'R', 'X', 'f', '5', '8', 'I', '0', 'R', 'Q', 'Y', 'Y', 'e', 'g', 'S', 't', '5', 'B', 'q', '8', '4', 'G', 'H', 'M', 'H', 'E', '9', '4', 'A', '4', 'S', 'Q', 'Z', 'e', ...
# C:\Users\Destiny\AppData\Local\Temp\ipykernel_20736\1056086961.py:35: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   out = F.softmax(self.fc3(out))
# 0.464015625
